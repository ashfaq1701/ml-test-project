# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 00:00:55,580 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 00:00:55,581 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-08 00:00:55,697 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 00:00:55,703 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 00:00:55,738 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:00:56,420 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 00:00:57,748 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 00:00:57,788 | INFO | distilbert_classifier.model | Starting 3-fold cross-validation
# 2025-12-08 00:00:58,056 | INFO | distilbert_classifier.model | Fold 1/3 | train=26666 | eval=13334
# 2025-12-08 00:00:58,108 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:00:58,791 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2085' max='2085' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2085/2085 15:48, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>417</td>
#       <td>0.413400</td>
#     </tr>
#     <tr>
#       <td>834</td>
#       <td>0.148500</td>
#     </tr>
#     <tr>
#       <td>1251</td>
#       <td>0.076100</td>
#     </tr>
#     <tr>
#       <td>1668</td>
#       <td>0.039300</td>
#     </tr>
#     <tr>
#       <td>2085</td>
#       <td>0.022900</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='417' max='417' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [417/417 00:30]
#     </div>
# 2025-12-08 00:17:19,442 | INFO | distilbert_classifier.model | Fold 1 accuracy: 0.9546
# 2025-12-08 00:17:19,442 | INFO | distilbert_classifier.model | Fold 2/3 | train=26667 | eval=13333
# 2025-12-08 00:17:19,499 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:17:20,174 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2085' max='2085' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2085/2085 15:32, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>417</td>
#       <td>0.416900</td>
#     </tr>
#     <tr>
#       <td>834</td>
#       <td>0.150400</td>
#     </tr>
#     <tr>
#       <td>1251</td>
#       <td>0.078200</td>
#     </tr>
#     <tr>
#       <td>1668</td>
#       <td>0.040800</td>
#     </tr>
#     <tr>
#       <td>2085</td>
#       <td>0.022000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='417' max='417' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [417/417 00:30]
#     </div>
# 2025-12-08 00:33:23,915 | INFO | distilbert_classifier.model | Fold 2 accuracy: 0.9551
# 2025-12-08 00:33:23,916 | INFO | distilbert_classifier.model | Fold 3/3 | train=26667 | eval=13333
# 2025-12-08 00:33:23,974 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:33:24,644 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2085' max='2085' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2085/2085 15:32, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>417</td>
#       <td>0.417800</td>
#     </tr>
#     <tr>
#       <td>834</td>
#       <td>0.148800</td>
#     </tr>
#     <tr>
#       <td>1251</td>
#       <td>0.077700</td>
#     </tr>
#     <tr>
#       <td>1668</td>
#       <td>0.043200</td>
#     </tr>
#     <tr>
#       <td>2085</td>
#       <td>0.024400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='417' max='417' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [417/417 00:30]
#     </div>
# 2025-12-08 00:49:28,306 | INFO | distilbert_classifier.model | Fold 3 accuracy: 0.9544
# 2025-12-08 00:49:28,306 | INFO | distilbert_classifier.model | Cross-validation accuracy: 0.9547 ± 0.0003
# 2025-12-08 00:49:28,316 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:49:29,494 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:157: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='854' max='2815' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 854/2815 06:20 < 14:35, 2.24 it/s, Epoch 1.52/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>563</td>
#       <td>0.355100</td>
#     </tr>
#   </tbody>
# </table><p>
