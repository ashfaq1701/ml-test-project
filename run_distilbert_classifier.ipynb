# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 02:39:29,118 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 02:39:29,118 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-08 02:39:29,239 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 02:39:29,245 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 02:39:29,279 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 02:39:29,962 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 02:39:31,287 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 02:39:31,326 | INFO | distilbert_classifier.model | Starting 5-fold cross-validation
# 2025-12-08 02:39:31,597 | INFO | distilbert_classifier.model | Fold 1/5 | train=32000 | eval=8000
# 2025-12-08 02:39:31,649 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 02:39:32,240 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 37:00, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.126500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.032100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.008300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003100</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:17]
#     </div>
# 2025-12-08 03:16:51,222 | INFO | distilbert_classifier.model | Fold 1 accuracy: 0.9619
# 2025-12-08 03:16:51,223 | INFO | distilbert_classifier.model | Fold 2/5 | train=32000 | eval=8000
# 2025-12-08 03:16:51,273 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 03:16:51,955 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 37:05, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.375200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.132000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.066600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.037100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.019000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:17]
#     </div>
# 2025-12-08 03:54:16,598 | INFO | distilbert_classifier.model | Fold 2 accuracy: 0.9593
# 2025-12-08 03:54:16,599 | INFO | distilbert_classifier.model | Fold 3/5 | train=32000 | eval=8000
# 2025-12-08 03:54:16,650 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 03:54:17,391 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 37:16, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.379400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.063800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.033000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.016000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005100</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001900</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:17]
#     </div>
# 2025-12-08 04:31:52,898 | INFO | distilbert_classifier.model | Fold 3 accuracy: 0.9601
# 2025-12-08 04:31:52,899 | INFO | distilbert_classifier.model | Fold 4/5 | train=32000 | eval=8000
# 2025-12-08 04:31:52,951 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 04:31:53,651 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 37:21, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.378600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067600</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.033800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:17]
#     </div>
# 2025-12-08 05:09:33,728 | INFO | distilbert_classifier.model | Fold 4 accuracy: 0.9614
# 2025-12-08 05:09:33,729 | INFO | distilbert_classifier.model | Fold 5/5 | train=32000 | eval=8000
# 2025-12-08 05:09:33,780 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 05:09:34,621 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 37:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.380000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.130500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.069500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.035600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001700</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:19]
#     </div>
# 2025-12-08 05:47:27,220 | INFO | distilbert_classifier.model | Fold 5 accuracy: 0.9623
# 2025-12-08 05:47:27,220 | INFO | distilbert_classifier.model | Cross-validation accuracy: 0.9610 ± 0.0011
# 2025-12-08 05:47:27,230 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 05:47:27,903 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:157: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5630' max='5630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5630/5630 41:51, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>563</td>
#       <td>0.353700</td>
#     </tr>
#     <tr>
#       <td>1126</td>
#       <td>0.122600</td>
#     </tr>
#     <tr>
#       <td>1689</td>
#       <td>0.062400</td>
#     </tr>
#     <tr>
#       <td>2252</td>
#       <td>0.030300</td>
#     </tr>
#     <tr>
#       <td>2815</td>
#       <td>0.014500</td>
#     </tr>
#     <tr>
#       <td>3378</td>
#       <td>0.006200</td>
#     </tr>
#     <tr>
#       <td>3941</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4504</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>5067</td>
#       <td>0.001200</td>
#     </tr>
#     <tr>
#       <td>5630</td>
#       <td>0.000500</td>
#     </tr>
#   </tbody>
# </table><p>
# 2025-12-08 06:29:29,021 | INFO | distilbert_classifier.model | Final model eval metrics: {'eval_loss': 0.2643907368183136, 'eval_accuracy': 0.9605, 'eval_runtime': 8.7884, 'eval_samples_per_second': 455.145, 'eval_steps_per_second': 14.223, 'epoch': 10.0}
# 2025-12-08 06:29:29,022 | INFO | distilbert_classifier.model | Generating predictions for test set
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-12-08 06:29:31,318 | INFO | distilbert_classifier.pipeline | Saved predictions to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_distilbert_classification.csv
# Predictions saved to: /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_distilbert_classification.csv
