# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-07 21:42:50,750 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-07 21:42:50,750 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-07 21:42:50,870 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-07 21:42:50,876 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-07 21:42:50,908 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# 2025-12-07 21:42:53,062 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-07 21:42:54,404 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-07 21:42:54,445 | INFO | distilbert_classifier.model | Starting 3-fold cross-validation
# 2025-12-07 21:42:54,700 | INFO | distilbert_classifier.model | Fold 1/3 | train=26666 | eval=13334
# 2025-12-07 21:42:54,752 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-07 21:42:55,366 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from distilbert_classifier import run_distilbert_pipeline
# ----> 3 output_path = run_distilbert_pipeline()
#       4 print(f"Predictions saved to: {output_path}")
#
# File ~/PycharmProjects/ml-interview-project-1/distilbert_classifier/pipeline.py:45, in run_distilbert_pipeline()
#      42 tokenized_train = tokenize_dataset(train_hf, tokenizer)
#      43 tokenized_test = tokenize_dataset(test_hf, tokenizer)
# ---> 45 run_cross_validation(
#      46     tokenized_train,
#      47     label_list=sorted(dataset_bundle.label2id.keys()),
#      48     output_dir=RESULTS_FILE.parent / "distilbert_cv",
#      49 )
#      51 dataset_splits = _train_eval_split(tokenized_train)
#      52 trainer = train_final_model(
#      53     tokenized_train=dataset_splits["train"],
#      54     tokenized_eval=dataset_splits["eval"],
#      55     label2id=dataset_bundle.label2id,
#      56     output_dir=RESULTS_FILE.parent / "distilbert_final",
#      57 )
#
# File ~/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:113, in run_cross_validation(tokenized_train, label_list, output_dir)
#     108 model = build_model({label: i for i, label in enumerate(label_list)})
#     109 data_collator = build_data_collator(tokenizer)
#     111 trainer = Trainer(
#     112     model=model,
# --> 113     args=_training_args(output_dir / f"fold_{fold_index}", evaluation=True),
#     114     train_dataset=fold_train,
#     115     eval_dataset=fold_eval,
#     116     tokenizer=tokenizer,
#     117     data_collator=data_collator,
#     118     compute_metrics=_compute_metrics,
#     119 )
#     121 trainer.train()
#     122 metrics = trainer.evaluate()
#
# File ~/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:74, in _training_args(output_dir, evaluation)
#      73 def _training_args(output_dir: Path, evaluation: bool = True) -> TrainingArguments:
# ---> 74     return TrainingArguments(
#      75         output_dir=str(output_dir),
#      76         per_device_train_batch_size=BATCH_SIZE,
#      77         per_device_eval_batch_size=BATCH_SIZE,
#      78         gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
#      79         learning_rate=LEARNING_RATE,
#      80         weight_decay=WEIGHT_DECAY,
#      81         num_train_epochs=NUM_EPOCHS,
#      82         evaluation_strategy="epoch" if evaluation else "no",
#      83         save_strategy="no",
#      84         logging_strategy="epoch",
#      85         load_best_model_at_end=False,
#      86         report_to=[],
#      87     )
#
# TypeError: TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'
