# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 00:56:49,058 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 00:56:49,059 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-08 00:56:49,175 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 00:56:49,181 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 00:56:49,213 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:56:50,246 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 00:56:51,579 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 00:56:51,619 | INFO | distilbert_classifier.model | Starting 5-fold cross-validation
# 2025-12-08 00:56:51,885 | INFO | distilbert_classifier.model | Fold 1/5 | train=32000 | eval=8000
# 2025-12-08 00:56:51,935 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 00:56:52,546 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 18:46, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.370300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.127900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.070100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.033900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.018100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:18]
#     </div>
# 2025-12-08 01:15:59,100 | INFO | distilbert_classifier.model | Fold 1 accuracy: 0.9599
# 2025-12-08 01:15:59,101 | INFO | distilbert_classifier.model | Fold 2/5 | train=32000 | eval=8000
# 2025-12-08 01:15:59,153 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 01:15:59,866 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 18:47, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.382400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.134200</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.069900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.037200</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.019700</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:18]
#     </div>
# 2025-12-08 01:35:06,475 | INFO | distilbert_classifier.model | Fold 2 accuracy: 0.9575
# 2025-12-08 01:35:06,476 | INFO | distilbert_classifier.model | Fold 3/5 | train=32000 | eval=8000
# 2025-12-08 01:35:06,528 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 01:35:07,212 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 18:47, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.381900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.136900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.072700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.037900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.019900</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:18]
#     </div>
# 2025-12-08 01:54:14,387 | INFO | distilbert_classifier.model | Fold 3 accuracy: 0.9573
# 2025-12-08 01:54:14,388 | INFO | distilbert_classifier.model | Fold 4/5 | train=32000 | eval=8000
# 2025-12-08 01:54:14,439 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 01:54:15,176 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 18:49, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.385400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.139900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.073200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.037900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.021400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:18]
#     </div>
# 2025-12-08 02:13:24,687 | INFO | distilbert_classifier.model | Fold 4 accuracy: 0.9566
# 2025-12-08 02:13:24,688 | INFO | distilbert_classifier.model | Fold 5/5 | train=32000 | eval=8000
# 2025-12-08 02:13:24,740 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 02:13:25,427 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 18:46, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.384900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.138100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.072000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.036700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.020700</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:18]
#     </div>
# 2025-12-08 02:32:31,060 | INFO | distilbert_classifier.model | Fold 5 accuracy: 0.9583
# 2025-12-08 02:32:31,061 | INFO | distilbert_classifier.model | Cross-validation accuracy: 0.9579 ± 0.0011
# 2025-12-08 02:32:31,072 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 02:32:31,738 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:157: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='793' max='2815' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 793/2815 05:57 < 15:12, 2.22 it/s, Epoch 1.41/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>563</td>
#       <td>0.355100</td>
#     </tr>
#   </tbody>
# </table><p>
