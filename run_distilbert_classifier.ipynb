# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 14:52:13,963 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 14:52:13,963 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/data/test.csv
# 2025-12-08 14:52:14,084 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 14:52:14,089 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 14:52:14,122 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 14:52:14,817 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 14:52:16,169 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 14:52:16,211 | INFO | distilbert_classifier.model | Starting 5-fold cross-validation
# 2025-12-08 14:52:16,478 | INFO | distilbert_classifier.model | Fold 1/5 | train=32000 | eval=8000
# 2025-12-08 14:52:16,528 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 14:52:17,156 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:19, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.126500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.031700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.008200</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-08 15:34:58,196 | INFO | distilbert_classifier.model | Fold 1 accuracy: 0.9621
# 2025-12-08 15:34:58,198 | INFO | distilbert_classifier.model | Fold 2/5 | train=32000 | eval=8000
# 2025-12-08 15:34:58,279 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 15:34:58,942 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:10, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.375200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.132100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.066500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.037400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.019500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001500</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:21]
#     </div>
# 2025-12-08 16:17:31,442 | INFO | distilbert_classifier.model | Fold 2 accuracy: 0.9585
# 2025-12-08 16:17:31,443 | INFO | distilbert_classifier.model | Fold 3/5 | train=32000 | eval=8000
# 2025-12-08 16:17:31,509 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 16:17:32,227 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:04, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.379400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.063700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.033000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-08 16:59:57,712 | INFO | distilbert_classifier.model | Fold 3 accuracy: 0.9611
# 2025-12-08 16:59:57,713 | INFO | distilbert_classifier.model | Fold 4/5 | train=32000 | eval=8000
# 2025-12-08 16:59:57,772 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 16:59:58,430 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:10, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.378600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.034100</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.002000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:21]
#     </div>
# 2025-12-08 17:42:31,373 | INFO | distilbert_classifier.model | Fold 4 accuracy: 0.9597
# 2025-12-08 17:42:31,374 | INFO | distilbert_classifier.model | Fold 5/5 | train=32000 | eval=8000
# 2025-12-08 17:42:31,440 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 17:42:32,086 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:15, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.379900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.130500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.069500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.036000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009400</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.002200</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001300</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:21]
#     </div>
# 2025-12-08 18:25:09,417 | INFO | distilbert_classifier.model | Fold 5 accuracy: 0.9621
# 2025-12-08 18:25:09,418 | INFO | distilbert_classifier.model | Cross-validation accuracy: 0.9607 ± 0.0014
# 2025-12-08 18:25:09,434 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 18:25:10,098 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:157: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5630' max='5630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5630/5630 47:50, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>563</td>
#       <td>0.353700</td>
#     </tr>
#     <tr>
#       <td>1126</td>
#       <td>0.122700</td>
#     </tr>
#     <tr>
#       <td>1689</td>
#       <td>0.062300</td>
#     </tr>
#     <tr>
#       <td>2252</td>
#       <td>0.030100</td>
#     </tr>
#     <tr>
#       <td>2815</td>
#       <td>0.015400</td>
#     </tr>
#     <tr>
#       <td>3378</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>3941</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>4504</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>5067</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>5630</td>
#       <td>0.000600</td>
#     </tr>
#   </tbody>
# </table><p>
# 2025-12-08 19:13:12,673 | INFO | distilbert_classifier.model | Final model eval metrics: {'eval_loss': 0.2529056966304779, 'eval_accuracy': 0.963, 'eval_runtime': 11.3216, 'eval_samples_per_second': 353.306, 'eval_steps_per_second': 11.041, 'epoch': 10.0}
# 2025-12-08 19:13:12,673 | INFO | distilbert_classifier.model | Generating predictions for test set
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-12-08 19:13:15,298 | INFO | distilbert_classifier.pipeline | Saved predictions to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/results/result_distilbert_classification.csv
# Predictions saved to: /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/results/result_distilbert_classification.csv
