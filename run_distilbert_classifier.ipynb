# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 13:56:23,046 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 13:56:23,047 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-08 13:56:23,170 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 13:56:23,177 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 13:56:23,210 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 13:56:23,897 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 13:56:25,235 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 13:56:25,276 | INFO | distilbert_classifier.model | Starting 5-fold cross-validation
# 2025-12-08 13:56:25,553 | INFO | distilbert_classifier.model | Fold 1/5 | train=32000 | eval=8000
# 2025-12-08 13:56:25,603 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 13:56:26,219 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/distilbert_classifier/model.py:124: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='4' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   4/5000 00:00 < 33:00, 2.52 it/s, Epoch 0.01/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
