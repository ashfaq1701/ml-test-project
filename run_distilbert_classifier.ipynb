# %%
from distilbert_classifier import run_distilbert_pipeline

output_path = run_distilbert_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 23:39:43,841 | INFO | distilbert_classifier.pipeline | Initializing DistilBERT classification workflow
# 2025-12-08 23:39:43,842 | INFO | distilbert_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/data/test.csv
# 2025-12-08 23:39:43,964 | INFO | distilbert_classifier.data | Shuffling training data with random state 42
# 2025-12-08 23:39:43,971 | INFO | distilbert_classifier.data | Finished loading datasets: train=40000 rows | test=1000 rows | classes=4
# 2025-12-08 23:39:44,007 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 23:39:44,712 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/40000 [00:00<?, ? examples/s]
# 2025-12-08 23:39:46,088 | INFO | distilbert_classifier.model | Tokenizing dataset with max_length=128
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# 2025-12-08 23:39:46,127 | INFO | distilbert_classifier.model | Starting 5-fold cross-validation
# 2025-12-08 23:39:46,388 | INFO | distilbert_classifier.model | Fold 1/5 | train=32000 | eval=8000
# 2025-12-08 23:39:46,439 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-08 23:39:47,035 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 40:20, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.369500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.126500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.031500</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-09 00:20:29,438 | INFO | distilbert_classifier.model | Fold 1 accuracy: 0.9615
# 2025-12-09 00:20:29,439 | INFO | distilbert_classifier.model | Fold 2/5 | train=32000 | eval=8000
# 2025-12-09 00:20:29,517 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-09 00:20:30,164 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 39:08, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.375300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.132000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.066500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.036800</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.018700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009700</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.002900</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001000</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:19]
#     </div>
# 2025-12-09 00:59:59,040 | INFO | distilbert_classifier.model | Fold 2 accuracy: 0.9594
# 2025-12-09 00:59:59,041 | INFO | distilbert_classifier.model | Fold 3/5 | train=32000 | eval=8000
# 2025-12-09 00:59:59,096 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-09 01:00:00,495 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:29, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.379400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.063800</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.033000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.015300</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.009300</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-09 01:42:52,011 | INFO | distilbert_classifier.model | Fold 3 accuracy: 0.9595
# 2025-12-09 01:42:52,020 | INFO | distilbert_classifier.model | Fold 4/5 | train=32000 | eval=8000
# 2025-12-09 01:42:52,236 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-09 01:42:53,085 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:31, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.378600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.131900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.067700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.034000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.017500</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.008800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.001600</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-09 02:25:46,260 | INFO | distilbert_classifier.model | Fold 4 accuracy: 0.9609
# 2025-12-09 02:25:46,261 | INFO | distilbert_classifier.model | Fold 5/5 | train=32000 | eval=8000
# 2025-12-09 02:25:46,328 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-09 02:25:46,980 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:123: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 42:15, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.379900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.130600</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.069500</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.036400</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.005600</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.001400</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:20]
#     </div>
# 2025-12-09 03:08:24,093 | INFO | distilbert_classifier.model | Fold 5 accuracy: 0.9616
# 2025-12-09 03:08:24,093 | INFO | distilbert_classifier.model | Cross-validation accuracy: 0.9606 ± 0.0010
# 2025-12-09 03:08:24,108 | INFO | distilbert_classifier.model | Loading tokenizer: distilbert-base-uncased
# 2025-12-09 03:08:24,728 | INFO | distilbert_classifier.model | Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/distilbert_classifier/model.py:157: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='5630' max='5630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5630/5630 47:30, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>563</td>
#       <td>0.353700</td>
#     </tr>
#     <tr>
#       <td>1126</td>
#       <td>0.122600</td>
#     </tr>
#     <tr>
#       <td>1689</td>
#       <td>0.062300</td>
#     </tr>
#     <tr>
#       <td>2252</td>
#       <td>0.029700</td>
#     </tr>
#     <tr>
#       <td>2815</td>
#       <td>0.015300</td>
#     </tr>
#     <tr>
#       <td>3378</td>
#       <td>0.007000</td>
#     </tr>
#     <tr>
#       <td>3941</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>4504</td>
#       <td>0.002400</td>
#     </tr>
#     <tr>
#       <td>5067</td>
#       <td>0.001400</td>
#     </tr>
#     <tr>
#       <td>5630</td>
#       <td>0.000600</td>
#     </tr>
#   </tbody>
# </table><p>
# 2025-12-09 03:56:06,644 | INFO | distilbert_classifier.model | Final model eval metrics: {'eval_loss': 0.2624332904815674, 'eval_accuracy': 0.96075, 'eval_runtime': 11.0648, 'eval_samples_per_second': 361.506, 'eval_steps_per_second': 11.297, 'epoch': 10.0}
# 2025-12-09 03:56:06,945 | INFO | distilbert_classifier.pipeline | Saved trained model to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/results/saved_models/distilbert
# 2025-12-09 03:56:06,948 | INFO | distilbert_classifier.model | Generating predictions for test set
# /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/.venv/lib/python3.10/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-12-09 03:56:09,548 | INFO | distilbert_classifier.pipeline | Saved predictions to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/results/result_distilbert_classification.csv
# Predictions saved to: /Users/ashfaqsalehin/PycharmProjects/ml-interview-project/results/result_distilbert_classification.csv
