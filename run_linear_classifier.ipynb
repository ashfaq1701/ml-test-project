# %%
from linear_classifier import run_linear_pipeline

output_path = run_linear_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-08 23:26:04,210 | INFO | linear_classifier.pipeline | Initializing linear classification workflow
# 2025-12-08 23:26:04,210 | INFO | linear_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-08 23:26:04,328 | INFO | linear_classifier.data | Shuffling training data with random state 42
# 2025-12-08 23:26:04,331 | INFO | linear_classifier.data | Finished loading datasets: train=40000 rows (3 cols), test=1000 rows (2 cols)
# 2025-12-08 23:26:04,333 | INFO | linear_classifier.data | Class distribution: {'twain': 10000, 'dickens': 10000, 'doyle': 10000, 'defoe': 10000}
# 2025-12-08 23:26:04,333 | INFO | linear_classifier.pipeline | Training samples: 40000 | Test samples: 1000
# 2025-12-08 23:26:04,334 | INFO | linear_classifier.features | Combining word and character TF-IDF vectorizers via FeatureUnion
# 2025-12-08 23:26:04,334 | INFO | linear_classifier.features | Building word TF-IDF | ngram_range=(1, 2) | max_features=20000
# 2025-12-08 23:26:04,334 | INFO | linear_classifier.features | Building character TF-IDF | ngram_range=(3, 5) | max_features=5000
# 2025-12-08 23:26:04,335 | INFO | linear_classifier.pipeline | Running 5-fold cross-validation
# 2025-12-08 23:26:04,336 | INFO | linear_classifier.model | Starting 5-fold cross-validation on 40000 samples
# 2025-12-08 23:26:30,383 | INFO | linear_classifier.model | Cross-validation accuracy: 0.9441 ± 0.0013
# 2025-12-08 23:26:30,383 | INFO | linear_classifier.model | Training final model on full dataset
# 2025-12-08 23:26:53,080 | INFO | linear_classifier.pipeline | Saved trained model to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/saved_models/linear_classifier/model.joblib
# 2025-12-08 23:26:53,390 | INFO | linear_classifier.pipeline | Saved predictions to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_linear_classification.csv
# Predictions saved to: /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_linear_classification.csv
