# %%
from linear_classifier import run_linear_pipeline

output_path = run_linear_pipeline()
print(f"Predictions saved to: {output_path}")
# Out:
# 2025-12-07 22:06:46,944 | INFO | linear_classifier.pipeline | Initializing linear classification workflow
# 2025-12-07 22:06:46,945 | INFO | linear_classifier.data | Loading datasets from /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/train.csv and /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/data/test.csv
# 2025-12-07 22:06:47,082 | INFO | linear_classifier.data | Shuffling training data with random state 42
# 2025-12-07 22:06:47,085 | INFO | linear_classifier.data | Finished loading datasets: train=40000 rows (3 cols), test=1000 rows (2 cols)
# 2025-12-07 22:06:47,087 | INFO | linear_classifier.data | Class distribution: {'twain': 10000, 'dickens': 10000, 'doyle': 10000, 'defoe': 10000}
# 2025-12-07 22:06:47,087 | INFO | linear_classifier.pipeline | Training samples: 40000 | Test samples: 1000
# 2025-12-07 22:06:47,088 | INFO | linear_classifier.features | Combining word and character TF-IDF vectorizers via FeatureUnion
# 2025-12-07 22:06:47,088 | INFO | linear_classifier.features | Building word TF-IDF | ngram_range=(1, 2) | max_features=20000
# 2025-12-07 22:06:47,088 | INFO | linear_classifier.features | Building character TF-IDF | ngram_range=(3, 5) | max_features=5000
# 2025-12-07 22:06:47,088 | INFO | linear_classifier.pipeline | Running 5-fold cross-validation
# 2025-12-07 22:06:47,090 | INFO | linear_classifier.model | Starting 5-fold cross-validation on 40000 samples
# 2025-12-07 22:07:13,189 | INFO | linear_classifier.model | Cross-validation accuracy: 0.9441 ± 0.0013
# 2025-12-07 22:07:13,190 | INFO | linear_classifier.model | Training final model on full dataset
# 2025-12-07 22:07:35,636 | INFO | linear_classifier.pipeline | Saved predictions to /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_linear_classification.csv
# Predictions saved to: /Users/ashfaqsalehin/PycharmProjects/ml-interview-project-1/results/result_linear_classification.csv
